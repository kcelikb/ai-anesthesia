# %%
import pandas as pd, seaborn as sns
sns.set()

# simple test plot
df = pd.DataFrame({"hello": [1, 2, 3]})
df.plot.bar(title="Environment Check")
# Out:
# <Axes: title={'center': 'Environment Check'}>
